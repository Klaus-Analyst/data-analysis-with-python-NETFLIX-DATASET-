# %%
import pandas as pd
df=pd.read_csv("Netflix Dataset.csv")
df
# Out:
#      Show_Id Category                                        Title  \
# 0         s1  TV Show                                           3%
# 1         s2    Movie                                        07:19
# 2         s3    Movie                                        23:59
# 3         s4    Movie                                            9
# 4         s5    Movie                                           21
# 5         s6  TV Show                                           46
# 6         s7    Movie                                          122
# 7         s8    Movie                                          187
# 8         s9    Movie                                          706
# 9        s10    Movie                                         1920
# 10       s11    Movie                                         1922
# 11       s12  TV Show                                         1983
# 12       s13  TV Show                                         1994
# ...

# %%
df.head()       #get the first five rows in the dataset
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.size
# Out:
# 85679

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#TASK 1: CHECK WHETHER THE DATA HAS DUPLICATES and remove the duplicates 
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#remove the duplicates 
df.drop_duplicates()
# Out:
#      Show_Id Category                                        Title  \
# 0         s1  TV Show                                           3%
# 1         s2    Movie                                        07:19
# 2         s3    Movie                                        23:59
# 3         s4    Movie                                            9
# 4         s5    Movie                                           21
# 5         s6  TV Show                                           46
# 6         s7    Movie                                          122
# 7         s8    Movie                                          187
# 8         s9    Movie                                          706
# 9        s10    Movie                                         1920
# 10       s11    Movie                                         1922
# 11       s12  TV Show                                         1983
# 12       s13  TV Show                                         1994
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7787, 11)

# %%
# TASK 2: CHECKING FOR NULL VALUES IN THE DATASET

df.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# 5       False     False  False     False  False    False         False
# 6       False     False  False     False  False    False         False
# 7       False     False  False     False  False    False         False
# 8       False     False  False     False  False    False         False
# 9       False     False  False     False  False    False         False
# 10      False     False  False     False  False    False         False
# 11      False     False  False      True  False    False         False
# ...

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sbs
sbs.heatmap(df.isnull())

# %%
#QUESTION 1: FOR THE HOUSE OF CARDS WHAT IS THNE SHOW ID AND WHO IS THE SHOW DIRECTOR 

df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df['Title']
# Out:
# 0                                                3%
# 1                                             07:19
# 2                                             23:59
# 3                                                 9
# 4                                                21
# 5                                                46
# 6                                               122
# 7                                               187
# 8                                               706
# 9                                              1920
# 10                                             1922
# 11                                             1983
# 12                                             1994
# 13                                            2,215
# 14                                             3022
# 15                                           Oct-01
# 16                                           Feb-09
# 17                                           22-Jul
# ...

# %%
import pandas as pd
df=pd.read_csv("Netflix Dataset.csv")
df
# Out:
#      Show_Id Category                                        Title  \
# 0         s1  TV Show                                           3%
# 1         s2    Movie                                        07:19
# 2         s3    Movie                                        23:59
# 3         s4    Movie                                            9
# 4         s5    Movie                                           21
# 5         s6  TV Show                                           46
# 6         s7    Movie                                          122
# 7         s8    Movie                                          187
# 8         s9    Movie                                          706
# 9        s10    Movie                                         1920
# 10       s11    Movie                                         1922
# 11       s12  TV Show                                         1983
# 12       s13  TV Show                                         1994
# ...

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
#creating a new column and grabbingv data from another

df['Data_N'] = pd.to_datetime(df['Release_Date'])

# %%
#which year had the highest number of TV shows and movies released.

df['Data_N'].dt.year.value_counts()
# Out:
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Data_N, dtype: int64

# %%
#which year had the highest number of TV shows and movies released. Show with bar graph 

df['Data_N'].dt.year.value_counts().plot(kind='bar')

# %%
#how many movies and TV shows are in the dataset
#df.head(2)
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
#how many movies and TV shows are in the dataset. show in a graph
import seaborn as sbs
sbs.countplot(df['Category'])

# %%
#Show the movies that were released in year 2000
#first create a column years and then filter movies ion year 2000

df['Year'] = df['Data_N'].dt.year

# %%
#Show the movies that were released in year 2000
#answer = there were no movies released in year 2000
df[ (df['Category'] == 'Movie') & (df['Year'] == 2000) ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Data_N, Year]
# Index: []

# %%
#Show the movies that were released in year 2016

df[ (df['Category']== 'Movie') & (df['Year']==2016) ]
# Out:
#      Show_Id Category                                              Title  \
# 1         s2    Movie                                              07:19
# 25       s26    Movie                                           (T)ERROR
# 35       s36    Movie                                          #Rucker50
# 59       s60    Movie                                    1000 Rupee Note
# 62       s63    Movie                                         13 Cameras
# 66       s67    Movie                                               13TH
# 102     s103    Movie                                3 Türken & ein Baby
# 115     s116    Movie                                        4th Man Out
# 133     s134    Movie                                             7 años
# 162     s163    Movie  A Christmas Special: Miraculous: Tales of Lady...
# 169     s170    Movie                                    A Family Affair
# 181     s182    Movie             A Grand Night In: The Story of Aardman
# ...

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Data_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
#show only the titles of TV shows that were released in india only 

df[ (df['Category']== 'TV Show') & (df['Country'] == 'India') ] ['Title']
# Out:
# 86                       21 Sarfarosh: Saragarhi 1897
# 132                                         7 (Seven)
# 340                                      Agent Raghav
# 364                                      Akbar Birbal
# 533                               Anjaan: Rural Myths
# 534                       Anjaan: Special Crimes Unit
# 686                       Bad Boy Billionaires: India
# 698                        Badalte Rishton Ki Dastaan
# 750                                     Bard of Blood
# 856                                            Betaal
# 879                                       Bh Se Bhade
# 880                                Bhaag Beanie Bhaag
# 881                                    Bhaage Re Mann
# 1316                                     Chhota Bheem
# 1377    ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# 1412                                  Classic Legends
# 1463                                  College Romance
# ...

# %%
#Show top 10 directors who gave the highest number of TV shows & movies on netflix 

df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Quentin Tarantino          8
# Name: Director, dtype: int64

# %%
#show all records where the category is Movie and the type is Comedies or country is United Kingdom 
df[(df['Category'] == 'Movie') & (df['Type'] == 'Comedies')]
# Out:
#      Show_Id Category                                              Title  \
# 33       s34    Movie                                       #realityhigh
# 72       s73    Movie                                           17 Again
# 84       s85    Movie                                          21 & Over
# 148     s149    Movie                               A Bad Moms Christmas
# 174     s175    Movie                        A Futile and Stupid Gesture
# 240     s241    Movie                                   A Thousand Words
# 317     s318    Movie                        Adventures in Public School
# 472     s473    Movie                       American Pie 9: Girls' Rules
# 522     s523    Movie                                   Anger Management
# 626     s627    Movie        Austin Powers: International Man of Mystery
# 692     s693    Movie                                     Bad Grandpa .5
# 795     s796    Movie                                        Bebe's Kids
# ...

# %%
#in how many movies, tom cruise was cast 
# filtering command doesnt apply in a record that has multiple elements 

df[ (df['Cast'] == 'Tom Cruise') ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Data_N, Year]
# Index: []

# %%
#this fucntion will create an error on a dataset that has null values 
df[df['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-5af05d9847e7> in <module>
# ----> 1 df[df['Cast'].str.contains('Tom Cruise')]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
# -> 2917         if com.is_bool_indexer(key):
#    2918             return self._getitem_bool_array(key)
#    2919
#
# ~\Anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     122             if not lib.is_bool_array(key):
#     123                 if isna(key).any():
# --> 124                     raise ValueError(na_msg)
#     125                 return False
#     126             return True
#
# ValueError: cannot index with vector containing NA / NaN values

# %%
#removing null values in the data

new_data = df.dropna()

# %%
new_data[new_data['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Data_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %%
#what are the different ratings defined by netflix
df['Rating'].nunique() # counts the number of unique elements in the column
# Out:
# 14

# %%
#what are the different ratings defined by netflix
df['Rating'].unique() #prints all unique functions in the data column.
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#How many movies got the 'TV-14' rating in Canada
df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14') & (df['Country'] == 'Canada')].shape
# Out:
# (11, 13)

# %%
#how many TV-shows got the 'R' rating after year 2018

df[(df['Category'] == 'TV Show') & (df['Rating'] == 'R') & (df['Year'] > 2018)].shape
# Out:
# (1, 13)

# %%
#what is the maximum duration of a movie/TV show at netflix 

df['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
#split the values to contain separate units 
df[['Minutes','Unit']] = df['Duration'].str.split(' ',expand=True)

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Data_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
df['Minutes'].max()
# Out:
# '99'

# %%
#which country has the highest No of TV shows 

data_tv_shows = df[df['Category'] == 'TV Show']
data_tv_shows.head(30)
# Out:
#     Show_Id Category                                Title  \
# 0        s1  TV Show                                   3%
# 5        s6  TV Show                                   46
# 11      s12  TV Show                                 1983
# 12      s13  TV Show                                 1994
# 16      s17  TV Show                               Feb-09
# 24      s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac
# 26      s27  TV Show                             (Un)Well
# 29      s30  TV Show                             #blackAF
# 38      s39  TV Show                  แผนร้ายนายเจ้าเล่ห์
# 45      s46  TV Show                                Şubat
# 51      s52  TV Show                   100 Days My Prince
# 53      s54  TV Show                           100 Humans
# 58      s59  TV Show                          100% Hotter
# 61      s62  TV Show                     12 Years Promise
# 63      s64  TV Show                       13 Reasons Why
# ...

# %%
data_tv_shows.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %%
#how can we sort the dataset by year 
#command is sort_values
#df.head(2)
df.sort_values(by='Year', ascending=False).head(10)
# Out:
#      Show_Id Category               Title                      Director  \
# 7353   s7352    Movie             Unknown            Jaume Collet-Serra
# 2013   s2014    Movie    Enter the Dragon                 Robert Clouse
# 2349   s2350    Movie           Gangaajal                   Prakash Jha
# 1497   s1498    Movie      Cool Hand Luke              Stuart Rosenberg
# 1194   s1195    Movie   Can't Hardly Wait  Harry Elfont, Deborah Kaplan
# 104     s105    Movie  30 Minutes or Less               Ruben Fleischer
# 692     s693    Movie      Bad Grandpa .5                 Jeff Tremaine
# 5139   s5139    Movie          Redemption                 Steven Knight
# 3521   s3522    Movie              Lagaan            Ashutosh Gowariker
# 5521   s5521    Movie  Sex and the City 2          Michael Patrick King
#
#                                                    Cast  \
# 7353  Liam Neeson, Diane Kruger, January Jones, Aida...
# 2013  Bruce Lee, John Saxon, Jim Kelly, Ahna Capri, ...
# ...

# %%
#find instances where category is 'Movie' and Type is 'drama' or catgory is 'TV Show' and Type is 'Kids Tv show'

df[(df['Category'] == 'Movie') & (df['Type'] == 'Dramas')| (df['Category'] == 'TV Show') & (df['Type'] == "Kids' TV")]
# Out:
#      Show_Id Category                                          Title  \
# 4         s5    Movie                                             21
# 7         s8    Movie                                            187
# 111     s112  TV Show                                        44 Cats
# 170     s171    Movie                                   A Family Man
# 232     s233    Movie                     A Stoning in Fulham County
# 276     s277  TV Show                                   Abby Hatcher
# 295     s296    Movie                             Across Grace Alley
# 308     s309    Movie                       Adam: His Song Continues
# 330     s331    Movie                                      Aftermath
# 334     s335    Movie                 Agatha and the Truth of Murder
# 422     s423    Movie                               All Together Now
# 429     s430    Movie                                Alone in Berlin
# 434     s435  TV Show                                    Alphablocks
# ...
